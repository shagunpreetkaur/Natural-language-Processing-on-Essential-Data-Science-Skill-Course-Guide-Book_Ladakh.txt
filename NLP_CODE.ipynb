# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-140c05af-86c5-467b-9011-0b3986736686" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-140c05af-86c5-467b-9011-0b3986736686">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
 with open("Essential Data Science Skill Course Guide Book_Ladakh.txt", 'r') as fh:
    filedata = fh.read()

# check contents (print first 200)
print("File data sample : ", filedata[:200])

# Create stopword list (standard list of words avaiable in the package)
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

# Generate wordcloud data
# Select top 50 words only
wordcloud = WordCloud(stopwords=stopwords, max_words=50, \
                      background_color="rgba(255, 255, 255, 0)").generate(filedata)
# Out:
# File data sample :  ﻿Essential Data Science Skill Course Guide Book
# The course guidebook is prepared to serve as an index document and step-by-step guide for recorded lectures, working notebooks, assignments, and dataset

# %% [markdown]
# WORD CLOUD GENERATION

# %%
from os import path
import matplotlib.pyplot as plt
from wordcloud import WordCloud

plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# Add more words to ignore
stopwords.update(["many","using", "want", "value"])

# Redo stop words. Limit number of words
wordcloud = WordCloud(stopwords=stopwords, max_words=50, \
                      background_color="black").generate(filedata)

plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
import nltk
import spacy
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# %% [markdown]
# STEMMING

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filedata:
    stemmed_words.append(ps.stem(w))

# %% [markdown]
# LEMMATIZATION AND STEMMING

# %%
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()


print("Lemmatized Word:",lem.lemmatize(filedata,"v"))
print("Stemmed Word:",stem.stem(filedata))
# Out:
# Lemmatized Word: ﻿Essential Data Science Skill Course Guide Book
# The course guidebook is prepared to serve as an index document and step-by-step guide for recorded lectures, working notebooks, assignments, and datasets of each module.
#
#
#
#
# General Instructions:
# Following are the general instructions for the course. Please go through them before starting the course:
#
#
# 1. Join the Slack workspace link for easy communications and course resource-sharing purposes.
#
#
# 2. All modules are designed and delivered in the python programming language. You can use GoogleColab via the  Link or install Anaconda from this link (https://www.anaconda.com/) to run your notebooks/code files.
#
#
# 3. All assignments will be submitted through the google form on this (link). In case of any issues, you can send them to erum@omdena.com.
#
#
# ...

# %% [markdown]
# DECISION TREE FOR PREDICTION

# %% [markdown]
# SPLITTING DATA

# %%
def evaluate_model(model, filedata):
    X_train, X_test, y_train, y_test = filedata
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    return accuracy_score(pred, y_test)

# %%
X = filedata

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
y = filedata

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
data=pd.read_csv('Essential Data Science Skill Course Guide Book_Ladakh.txt', sep='\t')
data.head()
# Out:
#       Essential Data Science Skill Course Guide Book
# 0  The course guidebook is prepared to serve as a...
# 1                              General Instructions:
# 2  Following are the general instructions for the...
# 3  1. Join the Slack workspace link for easy comm...
# 4  2. All modules are designed and delivered in t...

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier().fit(X_train, y_train)

print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))

# %% [markdown]
# Remove punctuation from text

# %%
import string

test_str = filedata

test_str = test_str.translate
(str.maketrans('', '', string.punctuation))
print(test_str)
# Out:
# <built-in method translate of str object at 0xc9a5e50>

# %% [markdown]
# N-GRAM

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk

word_data = filedata
nltk_tokens = nltk.word_tokenize(word_data)

print(list(nltk.bigrams(nltk_tokens)))
# Out:
# [('\ufeffEssential', 'Data'), ('Data', 'Science'), ('Science', 'Skill'), ('Skill', 'Course'), ('Course', 'Guide'), ('Guide', 'Book'), ('Book', 'The'), ('The', 'course'), ('course', 'guidebook'), ('guidebook', 'is'), ('is', 'prepared'), ('prepared', 'to'), ('to', 'serve'), ('serve', 'as'), ('as', 'an'), ('an', 'index'), ('index', 'document'), ('document', 'and'), ('and', 'step-by-step'), ('step-by-step', 'guide'), ('guide', 'for'), ('for', 'recorded'), ('recorded', 'lectures'), ('lectures', ','), (',', 'working'), ('working', 'notebooks'), ('notebooks', ','), (',', 'assignments'), ('assignments', ','), (',', 'and'), ('and', 'datasets'), ('datasets', 'of'), ('of', 'each'), ('each', 'module'), ('module', '.'), ('.', 'General'), ('General', 'Instructions'), ('Instructions', ':'), (':', 'Following'), ('Following', 'are'), ('are', 'the'), ('the', 'general'), ('general', 'instructions'), ('instructions', 'for'), ('for', 'the'), ('the', 'course'), ('course', '.'), ('.', 'Please'), ('Please',
# ...
